# %% [markdown]
# Markdown to Jupyter notebook example
# ====================================
#
# Here is a SugarTeX example with eq. 1 and fig. 1.
#
# See [PDF of this
# source](https://github.com/kiwi0fruit/sugartex/raw/master/sugartex.pdf)
# if you do not have [excellent Unicode
# support](https://github.com/kiwi0fruit/sugartex#atom-editor-with-full-unicode-support).
#
# <span id="eq:max">$$
# \begin{aligned}∇ × {\mathbf{B}} - \frac{1}{c} \frac{∂{\mathbf{E}}}{∂t} &= \frac{4π}{c} {\mathbf{j}}\\
#                ∇ ⋅ {\mathbf{E}}\ &= 4πρ       \\
#  ∇ × {\mathbf{E}} + \frac{1}{c} \frac{∂{\mathbf{B}}}{∂t} &= {\mathbf{0}}      \\
#                ∇ ⋅ {\mathbf{B}}\ &= 0         \end{aligned}
# ,\qquad(1)$$</span>
#
# where ${\mathbf{B}},\,{\mathbf{E}},\,{\mathbf{j}}:\,ℝ^{4} → ℝ^{3}$ –
# vector functions of the form
# $(t,x,y,z) ↦ {\mathbf{f}}(t,x,y,z),\,{\mathbf{f}} = (f_{\mathrm{x}}, f_{\mathrm{y}}, f_{\mathrm{z}})$.
#
# <figure><img src="data:image/png;base64,..." alt="Figure 1: Sample image with cross-references." id="fig:img" /><figcaption>Figure 1: Sample image with cross-references.</figcaption></figure>
#
# In this version of Pandoc image caption fig. 1 works but for some reason
# this text is not inside:
#
# ``` html
# <p></p>
# ```
#
# ``` python
# from IPython.display import Markdown
# import pandas as pd
# import numpy as np
# import tabulatehelper as th
#
# df = pd.DataFrame(np.random.random(16).reshape(4, 4))
#
# Markdown(f'''
# {th.md_table(df)}
# : Table {{#tbl:table1}}
# ''')
# ```
#
# <table>
# <caption>Table 1: Table</caption>
# <thead>
# <tr class="header">
# <th style="text-align: right;">0</th>
# <th style="text-align: right;">1</th>
# <th style="text-align: right;">2</th>
# <th style="text-align: right;">3</th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td style="text-align: right;">0.818013</td>
# <td style="text-align: right;">0.817791</td>
# <td style="text-align: right;">0.630244</td>
# <td style="text-align: right;">0.76844</td>
# </tr>
# <tr class="even">
# <td style="text-align: right;">0.310528</td>
# <td style="text-align: right;">0.587805</td>
# <td style="text-align: right;">0.487181</td>
# <td style="text-align: right;">0.407834</td>
# </tr>
# <tr class="odd">
# <td style="text-align: right;">0.212734</td>
# <td style="text-align: right;">0.252828</td>
# <td style="text-align: right;">0.729936</td>
# <td style="text-align: right;">0.120971</td>
# </tr>
# <tr class="even">
# <td style="text-align: right;">0.369216</td>
# <td style="text-align: right;">0.648964</td>
# <td style="text-align: right;">0.505223</td>
# <td style="text-align: right;">0.125527</td>
# </tr>
# </tbody>
# </table>
#
# Text and tbl. 1

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.random(16).reshape(4, 4))
df
# Out:
#           0         1         2         3
# 0  0.607076  0.412486  0.253888  0.478755
# 1  0.235017  0.212927  0.951879  0.021378
# 2  0.542342  0.978385  0.369996  0.281080
# 3  0.223882  0.532410  0.595636  0.366703

# %% [markdown]
# ``` r
# # R cell:
# x <- c(10, 20)
# x[1]
# ```
#
# 10
#
# Header
# ======
#
# ``` r
# x <- c(10, 20)
# x[1]
# ```
#
# 10
#
# ``` python
# import math
# Markdown(f'''
# Markdown text with SugarTeX formula: $α^˱{math.pi:1.3f}˲$.
# It works because of the Markdown display option and SugarTeX Pandoc filter.
# ''')
# ```
#
# Markdown text with SugarTeX formula: $α^{3.142}$. It works because of
# the Markdown display option and SugarTeX Pandoc filter.

# %%
print('Hello!')
# Out:
# Hello!
